# %%
import argparse
import warnings
import os 
from modeltest.get_selection import test
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '3'
warnings.filterwarnings("ignore")

# %%
### Selection Model testing
model=test('../data/test/input/',
           '../model/test/C3_Top_Selection_Model_Weight.hdf5',
           '../data/test/output_csv/C3_Top_Slice_Prediction.csv')
# Out:
# Metal device set to: Apple M1 Pro
#
#
#
#  loaded: ../model/test/C3_Top_Selection_Model_Weight.hdf5
# 4/4 [==============================] - 1s 57ms/step
# 0  th image, path:  ../data/test/input/mdacc_HNSCC-01-0589_CT-SIM-11-13-2011-_raw_raw_raw_xx.nrrd
#  C3_Predict_slice: 44
#
# 10/10 [==============================] - 1s 84ms/step
# 1  th image, path:  ../data/test/input/mdacc_HNSCC-01-0590_CT-SIM-11-13-2011-_raw_raw_raw_xx.nrrd
#  C3_Predict_slice: 76
#
# 10/10 [==============================] - 1s 108ms/step
# 2  th image, path:  ../data/test/input/mdacc_HNSCC-01-0591_CT-SIM-11-13-2011-_raw_raw_raw_xx.nrrd
#  C3_Predict_slice: 93
#
# 10/10 [==============================] - 2s 185ms/step
# 3  th image, path:  ../data/test/input/mdacc_HNSCC-01-0592_CT-SIM-12-16-2012-_raw_raw_raw_xx.nrrd
#  C3_Predict_slice: 77
#
# 10/10 [==============================] - 1s 150ms/step
# 4  th image, path:  ../data/test/input/mdacc_HNSCC-01-0593_CT-SIM-12-16-2012-_raw_raw_raw_xx.nrrd
# ...

# %%
### Segmentation Model testing
from modeltest.get_segmentation import test

model=test('../data/test/input',
           '../model/test/C3_Top_Segmentation_Model_Weight.hdf5',
           '../data/test/output_csv/C3_Top_Slice_Prediction.csv',
           '../data/test/output_segmentation/')
# Out:
# Metal device set to: Apple M1 Pro
# c3 slice
# 56
# 1/1 [==============================] - 0s 299ms/step
# (512, 512)
# (1, 512, 512)
#
# 0 th image: mdacc_HNSCC-01-0589_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 56 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0589_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 274
# 1/1 [==============================] - 0s 63ms/step
# (512, 512)
# (1, 512, 512)
#
# 1 th image: mdacc_HNSCC-01-0590_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 274 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0590_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 222
# 1/1 [==============================] - 0s 64ms/step
# (512, 512)
# (1, 512, 512)
#
# 2 th image: mdacc_HNSCC-01-0591_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 222 )  segmentation_in_NIFTI saved into
# ...
