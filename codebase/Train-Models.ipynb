# %%
import numpy as np
import argparse
from modeltrain.slice_prediction import train
from util import data_generator
import os
import warnings
import scipy.integrate

os.environ["TF_CPP_MIN_LOG_LEVEL"] = '3'
warnings.filterwarnings("ignore")

# %%
### Train Slice Prediction Model
model = train('../data/train/train_prediction/','../model/')

# %%
### Train Segmentatio Model
from modeltrain.segmentation import train
model=train('../data/train/train_segmentation/','../model/train/unet_models/')
