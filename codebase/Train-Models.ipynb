# %%
import numpy as np
import argparse
from modeltrain.slice_selection import train
from util import data_generator
import os
import warnings
import scipy.integrate

os.environ["TF_CPP_MIN_LOG_LEVEL"] = '3'
warnings.filterwarnings("ignore")

# %%
model = train('../data/train/train_selection/','../model/')
# Out:
#  train_labels.shape: (72484,) tuning_labels.shape: (17830,)
#
#
#
# Compiling model
# Starting training...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 model = train('../data/train/train_selection/','../model/')
#
# File ~/Desktop/Science Reach/root/codebase/modeltrain/slice_selection.py:128, in train(data_dir, model_dir, epochs, name, batch_size, load_weights, gpus, learning_rate, threshold, nb_layers_per_block, nb_blocks, nb_initial_filters, growth_rate, compression_rate, activation, initializer, batch_norm, wandb_callback)
#     122   print('Starting training...')
#     123 #  history = parallel_model.fit_generator(train_generator, epochs=epochs,
#     124 #                               shuffle=False, validation_data=val_generator,
#     125 #                               callbacks=model_callbacks,
# ...

# %%
from modeltrain.segmentation import train
model=train('../data/train/train_segmentation/','../model/train/unet_models/')
# Out:
# compression channels
# [16, 32, 64, 128, 256, 512]
# decompression channels
# [256, 128, 64, 32, 16]
#
#
#
# images_train.shape,images_val.shape (280, 512, 512, 1) (70, 512, 512, 1)
#
#
#
# Creating and compiling model...
# Metal device set to: Apple M1 Pro
#
#
#   val_batches:::: 70
#
#
#
#   train_batches:::: 280
#
# Fitting model...
#                                        Learning Rate Update at Epoch 0
# Lr 0.0005
# Epoch 1/200
# 280/280 [==============================] - 59s 204ms/step - loss: -0.5548 - val_loss: -0.5576 - lr: 5.0000e-04
#                                        Learning Rate Update at Epoch 1
# Lr 0.0005
# Epoch 2/200
# 280/280 [==============================] - 56s 202ms/step - loss: -0.8375 - val_loss: -0.8680 - lr: 5.0000e-04
#                                        Learning Rate Update at Epoch 2
# Lr 0.0005
# Epoch 3/200
# 280/280 [==============================] - 57s 202ms/step - loss: -0.8721 - val_loss: -0.1669 - lr: 5.0000e-04
# ...
