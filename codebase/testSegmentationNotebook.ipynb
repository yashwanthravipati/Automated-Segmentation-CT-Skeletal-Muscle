# %%
import argparse
import os
import warnings
from modeltest.get_segmentation import test

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '3'
warnings.filterwarnings("ignore")
   
#if __name__ == '__main__':

#    parser = argparse.ArgumentParser(description='Bodycomposition is segmented and stored in NIFTI format.') 
    
#    parser.add_argument('--image_dir','-i', type = str, default = '../data/test/input', 
#                        help = 'File path of abdominal CT scan')
    
#    parser.add_argument('--model_weight_path','-m', type = str, default = '../model/test/L3_Top_Segmentation_Model_Weight.hdf5',
#                        help = 'File path of well-trained model weight')
    
#    parser.add_argument('--l3_slice_csv_path','-c', type = str, default = '../data/test/output_csv/L3_Top_Slice_Prediction.csv',
#                        help = 'L3 top slice number of the input CT scan')
    
#    parser.add_argument('--output_dir','-o', type = str, 
#                        default = '../data/test/output_segmentation/',
#                        help = 'File path of well-trained model weight')    
    
#    args = parser.parse_args()
#    model = test(**vars(args))

# %%
model=test('../data/test/input','../model/test/C3_Top_Segmentation_Model_Weight.hdf5','../data/test/output_csv/C3_Top_Slice_Prediction.csv','../data/test/output_segmentation/')
# Out:
# Metal device set to: Apple M1 Pro
# 2022-12-13 15:39:57.376490: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-13 15:39:57.376605: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# c3 slice
# 268
# 2022-12-13 15:39:59.236067: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-13 15:39:59.715430: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 1s/step
# (256, 256)
# (1, 256, 256)
#
# 0 th image: mdacc_HNSCC-01-0005_CT-SIM-01-19-1998-_raw_raw_raw_xx (C3_slice_auto: 268 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0005_CT-SIM-01-19-1998-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 128
# 1/1 [==============================] - 0s 67ms/step
# (256, 256)
# (1, 256, 256)
#
# 1 th image: mdacc_HNSCC-01-0006_CT-SIM-06-09-1997-_raw_raw_raw_xx (C3_slice_auto: 128 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0006_CT-SIM-06-09-1997-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 85
# 1/1 [==============================] - 0s 66ms/step
# (256, 256)
# (1, 256, 256)
#
# 2 th image: mdacc_HNSCC-01-0095_CT-SIM-09-22-1999-_raw_raw_raw_xx (C3_slice_auto: 85 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0095_CT-SIM-09-22-1999-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 78
# 1/1 [==============================] - 0s 41ms/step
# (256, 256)
# (1, 256, 256)
#
# 3 th image: mdacc_HNSCC-01-0096_CT-SIM-10-30-1999-_raw_raw_raw_xx (C3_slice_auto: 78 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0096_CT-SIM-10-30-1999-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 158
# 1/1 [==============================] - 0s 34ms/step
# (256, 256)
# (1, 256, 256)
#
# 4 th image: mdacc_HNSCC-01-0581_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 158 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0581_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 55
# 1/1 [==============================] - 0s 58ms/step
# (256, 256)
# (1, 256, 256)
#
# 5 th image: mdacc_HNSCC-01-0582_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 55 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0582_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 147
# 1/1 [==============================] - 0s 33ms/step
# (256, 256)
# (1, 256, 256)
#
# 6 th image: mdacc_HNSCC-01-0583_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 147 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0583_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 154
# 1/1 [==============================] - 0s 62ms/step
# (256, 256)
# (1, 256, 256)
#
# 7 th image: mdacc_HNSCC-01-0584_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 154 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0584_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# c3 slice
# 139
# 1/1 [==============================] - 0s 53ms/step
# (256, 256)
# (1, 256, 256)
#
# 8 th image: mdacc_HNSCC-01-0585_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 139 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0585_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 model=test('../data/test/input','../model/test/C3_Top_Segmentation_Model_Weight.hdf5','../data/test/output_csv/C3_Top_Slice_Prediction.csv','../data/test/output_segmentation/')
#
# File ~/Desktop/aim_copy4/aim_copy3/Body_composition_C3_code/BodyComposition_C3-main/src/scripts/infer_segmentation.py:27, in test(image_dir, model_weight_path, l3_slice_csv_path, output_dir)
#      24 infer_3d_path = output_dir + patient_id + '.seg.nrrd'
#      26 image_path = get_image_path_by_id(patient_id,image_dir)
# ---> 27 image_sitk =  sitk.ReadImage(image_path)
#      28 #image_sitk = resample_sitk_image(image_sitk1, new_spacing=[1, 1, 3],new_size= None, interpolator=sitk.sitkLinear)
#      30 image_array_3d  = sitk.GetArrayFromImage(image_sitk)
#
# File ~/miniforge3/envs/env_tf1/lib/python3.9/site-packages/SimpleITK/extra.py:346, in ReadImage(fileName, outputPixelType, imageIO)
#     344 reader.SetImageIO(imageIO)
#     345 reader.SetOutputPixelType(outputPixelType)
# --> 346 return reader.Execute()
#
# File ~/miniforge3/envs/env_tf1/lib/python3.9/site-packages/SimpleITK/SimpleITK.py:8015, in ImageFileReader.Execute(self)
#    8009 def Execute(self):
#    8010     r"""
#    8011     Execute(ImageFileReader self) -> Image
#    8012
#    8013
#    8014     """
# -> 8015     return _SimpleITK.ImageFileReader_Execute(self)
#
# RuntimeError: Exception thrown in SimpleITK ImageFileReader_Execute: /tmp/SimpleITK/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "" does not exist.
